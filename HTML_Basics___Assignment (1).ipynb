# %% [markdown]
# HTML Basics | Assignment
#
#  1)  Explain the basic structure of an HTML page. Why is it important to follow
# this structure?
#
#      - a) An HTML page has a basic structure that includes the DOCTYPE declaration, the HTML tag, the head section, and the body section. The head contains information about the page such as the title and metadata, while the body contains the visible content shown on the webpage.
#
#        b) Following this structure is important because it helps browsers display the page correctly, makes the code easy to understand, improves accessibility, and ensures compatibility with different browsers and devices

# %%
#Question 2) You’re building a small personal profile page. Which HTML tags will you use to highlight your name as a heading, describe yourself in a paragraph, and emphasize a key skill?
'''
To build a small personal profile page, I would use the <h1> tag to highlight my name as a heading, the <p> tag to describe myself in a paragraph, and the <strong> or <em> tag to emphasize a key skill.
'''
# Out:
# '\nTo build a small personal profile page, I would use the <h1> tag to highlight my name as a heading, the <p> tag to describe myself in a paragraph, and the <strong> or <em> tag to emphasize a key skill. \n'

# %%
#Question 3)Look at the code below. Can you find and fix the mistake?
<!-- This is an HTML comment
<h1>Welcome to my website</h1>

'''
The mistake is that the HTML comment is not closed.
HTML comments must start with <!-- and end with -->.

<!-- This is an HTML comment -->
<h1>Welcome to my website</h1>

'''
# Out:
#   File "/tmp/ipython-input-3128714401.py", line 2
#     <!-- This is an HTML comment
#     ^
# SyntaxError: invalid syntax

# %%
# Question 4) You’re creating a form that asks the user to enter their name, select their country from a list, and click a button to submit. Write the HTML code for this
'''
<!DOCTYPE html>
<html>
<head>
  <title>User Form</title>
</head>
<body>

  <h2>User Information Form</h2>
  <form>
    <label>Name:</label><br>
    <input type="text" name="name"><br><br>
    <label>Country:</label><br>
    <select name="country">
      <option>India</option>
      <option>USA</option>
      <option>UK</option>
    </select><br><br>
    <button type="submit">Submit</button>
  </form>

</body>
</html>

'''
# Out:
# '\n<!DOCTYPE html>\n<html>\n<head>\n  <title>User Form</title>\n</head>\n<body>\n\n  <h2>User Information Form</h2>\n  <form>\n    <label>Name:</label><br>\n    <input type="text" name="name"><br><br>\n    <label>Country:</label><br>\n    <select name="country">\n      <option>India</option>\n      <option>USA</option>\n      <option>UK</option>\n    </select><br><br>\n    <button type="submit">Submit</button>\n  </form>\n\n</body>\n</html>\n\n'

# %%
# Question 5) Write short HTML code to show your favorite fruits in a bulleted list and your top 3 programming languages in a numbered lis
'''
<!DOCTYPE html>
<html>
<body>

<h3>Favorite Fruits</h3>
<ul>
  <li>Apple</li>
  <li>Mango</li>
  <li>Banana</li>
</ul>

<h3>Top 3 Programming Languages</h3>
<ol>
  <li>Python</li>
  <li>Java</li>
  <li>JavaScript</li>
</ol>

</body>
</html>

'''
# Out:
# '\n<!DOCTYPE html>\n<html>\n<body>\n\n<h3>Favorite Fruits</h3>\n<ul>\n  <li>Apple</li>\n  <li>Mango</li>\n  <li>Banana</li>\n</ul>\n\n<h3>Top 3 Programming Languages</h3>\n<ol>\n  <li>Python</li>\n  <li>Java</li>\n  <li>JavaScript</li>\n</ol>\n\n</body>\n</html>\n\n'

# %%
#Question 6)  Ravi wants to leave a note in his HTML file so that only other developers
can see it, not the users on the website. How should he do this? Why are such notes
useful?
'''
Ravi should use HTML comments:
<!-- This is a note for developers -->

'''
# Out:
#   File "/tmp/ipython-input-388197415.py", line 2
#     can see it, not the users on the website. How should he do this? Why are such notes
#         ^
# SyntaxError: invalid syntax

# %%
#Question 7)  Here’s a form snippet. Can you spot the error and rewrite the correct
version?
<form>
 <input name="email">
 <select>
 <option>India</option>
 </select>
 <button>Send</buton>
</form>

'''
<form>
  <input type="email" name="email">
  <select>
    <option>India</option>
  </select>
  <button>Send</button>
</form>


( <input type="email" name="email">)type="email" is misssing
'''
# Out:
#   File "/tmp/ipython-input-316917115.py", line 3
#     <form>
#     ^
# SyntaxError: invalid syntax
